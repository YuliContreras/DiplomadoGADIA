# %% [markdown]
# ACTIVIDAD

# %%
# Declarar las variables a y b
a = 10
b = 3

# %%
# Suma
s= a+b
print(a+b)
# Out:
# 13

# %%
# Resta
r= a-b
print(a-b)
# Out:
# 7

# %%
# Multiplicación
m= a*b
print(a*b)
# Out:
# 30

# %%
# División
d= a/b
print(a/b)
# Out:
# 3.3333333333333335

# %%
# Módulo
m= a%b
print(a%b)
# Out:
# 1

# %%
# Potencia
p= a**b
print(a**b)
# Out:
# 1000

# %%
# División entera
d_e= a//b
print(a//b)
# Out:
# 3

# %% [markdown]
# ## 5. Textos o valores string
#
# En Python los valores de cadena se identifican a traves de "STR"

# %%
cadena_simple="Hola, mundo"
cadena_doble="Hola, mundo"
cadena_multiple="""Esta es
una cadena
que ocupa
varias lineas"""

# %%
#Operaciones basicas con cadenas
#La concatenacion
saludo="Hola"
nombre="Mundo"
mensaje=saludo+", "+nombre
print(mensaje)
# Out:
# Hola, Mundo

# %%
#La repeticion
repetir="hola"*3
print(repetir)
# Out:
# holaholahola

# %%
#La indexacion: Acceder a caracteres individuales usando indices.
primer_caracter=mensaje[0]
print(primer_caracter)
# Out:
# H

# %%
#Slicing: Obtiene subcadenas usando una notacion de rango
#Obtener la palabra "Hola" de la variable mensaje
sub_cadena=mensaje[0:4]
print(sub_cadena)
# Out:
# Hola

# %%
cadena="python es genial"
#metodos de cadenas
#MAYUSCULAS
print(cadena.upper())
#minusculas
print(cadena.lower())
#tipo titulo
print(cadena.strip())
#remplazo de caracteres
print(cadena.replace("genial","increible"))
#separacion de cadenas
print(cadena.split(" "))
#union de cadenas
print(",".join(["python es genial"]))
# Out:
# PYTHON ES GENIAL
# python es genial
# python es genial
# python es increible
# ['python', 'es', 'genial']
# python es genial

# %% [markdown]
# ## 6. Estructura de datos

# %% [markdown]
# ![imagen (1).png](data:image/png;base64,...)

# %%
#Listas: """
"""
Las listas en Python son una de las estructuras de datos más utilizadas debido a su flexibilidad y capacidad para almacenar diferentes tipos de datos. Aquí te explico en detalle cómo funcionan las listas y cómo puedes utilizarlas"""

# %%
#Creando una lista basica
mi_lista=[]

#Crear lista con elementos
mi_lista=[1,2,3,"cuatro",5.0,True]

#Accediendo a elementos de la lista
mi_lista = [10, 20, 30, 40, 50]

#Acceder al tercer elemento
print(mi_lista[2])

#Acceder al ultimo elemento
print(mi_lista[-1])
# Out:
# 30
# 50

# %%
#Modificacion de listas
#Cambian  en mi lista el 30 por 1
mi_lista[2]=1
print(mi_lista)
# Out:
# [10, 20, 1, 40, 50]

# %%
#Agregar nuevos elementos a una lista
mi_lista=[1,2,3]

#Agregar un elemento al final de la lista
mi_lista.append(4)

print(mi_lista)
# Out:
# [1, 2, 3, 4]

# %%
#Insertar un elemento en la lista en una posicion especifica
mi_lista.insert(1,1.5)
print(mi_lista)
# Out:
# [1, 1.5, 2, 3, 4]

# %%
#Agregar varios elementos a una lista
mi_lista.extend([5,6])
print(mi_lista)
# Out:
# [1, 1.5, 2, 3, 4, 5, 6]

# %%
#eliminar elementos de las listas
mi_lista.remove(1)
print(mi_lista)
# Out:
# [1.5, 2, 3, 4, 5, 6]

# %%
#Eliminacion de elementos por una posicion especifica
del mi_lista[0]
print(mi_lista)
# Out:
# [2, 3, 4, 5, 6]

# %%
realizar punto 1 de la actividad

# %%
#ejercicio 2 creacion de tuplas
colores=("rojo","verde","azul")

# %%
seguir aqui con el punto 2

# %%
#Diccionarios
""" En Python, los diccionarios son una estructura de datos muy versátil y útil.
Son colecciones no ordenadas de pares clave-valor, donde cada clave es única y se asocia a un valor. Aquí te explico los aspectos básicos y algunas características avanzadas"""
# Out:
# ' En Python, los diccionarios son una estructura de datos muy versátil y útil. \nSon colecciones no ordenadas de pares clave-valor, donde cada clave es única y se asocia a un valor. Aquí te explico los aspectos básicos y algunas características avanzadas'

# %%
mi_diccionario={
    "nombre":"Ana",
    "edad": 30,
    "ciudad": "Bogota"
    }

# %%
#Agregar elementos a un diccionario
inventario={}
inventario["manzanas"]=50
inventario["naranjas"]=30

print(inventario)
# Out:
# {'manzanas': 50, 'naranjas': 30}

# %%
#Acceso a los elementos de un diccionario se hace a partir del nombre del elemento
print(mi_diccionario["edad"])
# Out:
# 30

# %%
#Modificar un elemento de un diccionario
mi_diccionario["edad"]=31
print(mi_diccionario)
# Out:
# {'nombre': 'Ana', 'edad': 31, 'ciudad': 'Bogota'}

# %%
#Eliminar elementos del diccionario
del mi_diccionario["ciudad"]
print(mi_diccionario)
# Out:
# {'nombre': 'Ana', 'edad': 31}
